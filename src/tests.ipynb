# %%
import numpy as np
import pandas as pd

# %%
GEO = "GEODGHR4"
GEN_015 = "GEN_015"
SDC_015 = "SDC_015"
NDVI = "NDVI"

# %%
data = pd.read_csv("C:\\Users\\xia_t\\Desktop\\Projects\\youreka\\dataset\\all_subsetted_group.csv")

# filter mental health and indigenous status
data = data.loc[data[SDC_015] <= 2]
data = data.loc[data[GEN_015] <= 5]

# %%
# normalize NDVI into a range of [0, 1]
n = data[NDVI]
data[NDVI] = (n - n.min()) / (n.max() - n.min())

# min 0.40255
# 0.53163_
# 0.660716_
# max 0.7898

# %%
# unique respondant identifier
import uuid

sample_n = len(data)
uuids = [str(uuid.uuid4()) for _ in range(sample_n)]
data["UUID"] = uuids

# %%
# categorize NDVI into N_BINS intervals
N_BINS = 3
bins = np.linspace(0, 1, N_BINS + 1)

for i in range(N_BINS):
    lower = bins[i]
    upper = bins[i + 1]

    inclusive = "right"
    if i == 0:
        inclusive = "both"

    data.loc[data["NDVI"].between(lower, upper, inclusive), "NDVI_BINS"] = i

data["NDVI"] = data["NDVI_BINS"]

# %%
from scipy.stats.contingency import crosstab
from scipy.stats import chi2_contingency
from scipy.stats.contingency import association

class TestResult:
    def __init__(self, chi2, cramer) -> None:
        self.chi2 = chi2
        self.cramer = cramer


def chi2_test(contingency_table, a = True):
    return TestResult(
        chi2_contingency(contingency_table, correction=True),
        association(contingency_table, method="cramer", correction=True) if a else None,
    )

def gen_table(cols, data):
    return crosstab(*[data[col] for col in cols]).count

def contingency_count_check(contingency_table):
    n_cells_check = np.sum(contingency_table >= 5)
    n_cells = np.multiply.reduce(contingency_table.shape)

    return (n_cells_check / n_cells) >= 0.8

# %%
from tqdm.notebook import trange

grouped_sdc_015 = data.groupby([SDC_015])
grouped_ndvi = data.groupby([NDVI])
grouped_inter = data.groupby([SDC_015, NDVI])

results_list = []

for i in trange(250):
    while True:
        data_sdc_015 = grouped_sdc_015.apply(lambda x: x.sample(67, random_state=i).reset_index(drop=True))
        contingency_sdc_015 = gen_table([SDC_015, GEN_015], data_sdc_015)
        if contingency_count_check(contingency_sdc_015):
            break
    sdc_015 = chi2_test(contingency_sdc_015)

    while True:
        data_ndvi = grouped_ndvi.apply(lambda x: x.sample(65, random_state=i).reset_index(drop=True))
        contingency_ndvi = gen_table([NDVI, GEN_015], data_ndvi)
        if contingency_count_check(contingency_ndvi):
            break
    ndvi = chi2_test(contingency_ndvi)
    
    while True:
        data_inter = grouped_inter.apply(lambda x: x.sample(47, random_state=i).reset_index(drop=True))
        contingency_inter = gen_table([SDC_015, NDVI, GEN_015], data_inter)
        if contingency_count_check(contingency_inter):
            break
    inter = chi2_test(contingency_inter, a=False)

    results_list.append((sdc_015, ndvi, inter, i))
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# 0.8
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# 0.6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 19
#      17 while True:
#      18     data_ndvi = grouped_ndvi.apply(lambda x: x.sample(65, random_state=i).reset_index(drop=True))
# ---> 19     contingency_ndvi = gen_table([NDVI, GEN_015], data_ndvi)
#      20     if contingency_count_check(contingency_ndvi):
#      21         break
#
# Cell In[21], line 18, in gen_table(cols, data)
#      17 def gen_table(cols, data):
# ---> 18     return crosstab(*[data[col] for col in cols]).count
#
# File c:\Users\xia_t\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_crosstab.py:168, in crosstab(levels, sparse, *args)
#     163     raise ValueError("When `sparse` is True, only two input sequences "
#     164                      "are allowed.")
#     166 if levels is None:
#     167     # Call np.unique with return_inverse=True on each argument.
# --> 168     actual_levels, indices = zip(*[np.unique(a, return_inverse=True)
#     169                                    for a in args])
#     170 else:
#     171     # `levels` is not None...
#     172     if len(levels) != nargs:
#
# File c:\Users\xia_t\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_crosstab.py:168, in <listcomp>(.0)
#     163     raise ValueError("When `sparse` is True, only two input sequences "
#     164                      "are allowed.")
#     166 if levels is None:
#     167     # Call np.unique with return_inverse=True on each argument.
# --> 168     actual_levels, indices = zip(*[np.unique(a, return_inverse=True)
#     169                                    for a in args])
#     170 else:
#     171     # `levels` is not None...
#     172     if len(levels) != nargs:
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File c:\Users\xia_t\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File c:\Users\xia_t\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:333, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     330 optional_indices = return_index or return_inverse
#     332 if optional_indices:
# --> 333     perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     334     aux = ar[perm]
#     335 else:
#
# KeyboardInterrupt:

# %%
TESTS = [
    SDC_015,
    NDVI,
    "INTER"
]

PROPERTIES = {
    "STATISTIC": lambda x: x.chi2.statistic,
    "PVALUE": lambda x: x.chi2.pvalue,
    "DOF": lambda x: x.chi2.dof,
    "CRAMERV": lambda x: x.cramer
}

cols = [
    f"{test}_{property_}"
    for test in TESTS
    for property_ in PROPERTIES
]
cols.append("SEED")
results = pd.DataFrame(index=np.arange(len(results_list)), columns=cols)

for i, res in enumerate(results_list):
    row = []
    for test in res[:-1]:
        for unpack_function in PROPERTIES.values():
            row.append(unpack_function(test))
    
    row.append(res[-1])
    results.loc[i] = row

# %%
results.to_csv("tests.csv")
